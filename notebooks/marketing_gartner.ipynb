# %%
import pandas as pd 
path = "/Users/servandodavidtorresgarcia/Servando/gartner/data/marketing_data.csv"
df = pd.read_csv(path, sep=";")

# %%
from tkinter import SE
from src.data.seasonality import SeasonalityInspector
inspector = SeasonalityInspector()

# %%
df.head()
# Out:
#   site country        date  total_spend  impressions  sessions  conversions
# 0  CAP      UK  2023-01-31     19051.08        38847     15450         1029
# 1  CAP      UK  2023-01-30     20011.97        39353     15497         1011
# 2  CAP      UK  2023-01-29     15314.75        27115     10758          480
# 3  CAP      UK  2023-01-28     13223.09        26754     10516          480
# 4  CAP      UK  2023-01-27     20017.61        39125     15361          960

# %%
df.date = pd.to_datetime(df.date)

# %%
df.head()
# Out:
#   site country       date  total_spend  impressions  sessions  conversions
# 0  CAP      UK 2023-01-31     19051.08        38847     15450         1029
# 1  CAP      UK 2023-01-30     20011.97        39353     15497         1011
# 2  CAP      UK 2023-01-29     15314.75        27115     10758          480
# 3  CAP      UK 2023-01-28     13223.09        26754     10516          480
# 4  CAP      UK 2023-01-27     20017.61        39125     15361          960

# %%
# check seasonaility of the data usisng statsmodel seasonal_decompose
from statsmodels.tsa.seasonal import seasonal_decompose

seasonal_decompose(df.set_index("date").sessions, model="additive", period=30).plot()

# %%
df_daily = df.groupby(['cohort', pd.Grouper(key='date', freq='D')])['total_spend', 'impressions', 'sessions', 'conversions'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/servandodavidtorresgarcia/Servando/Relu/Relu/notebooks/marketing_gartner.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/servandodavidtorresgarcia/Servando/Relu/Relu/notebooks/marketing_gartner.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> df_daily = df.groupby(['cohort', pd.Grouper(key='date', freq='D')])['total_spend', 'impressions', 'sessions', 'conversions'].sum()
#
# File ~/miniconda3/envs/relu/lib/python3.8/site-packages/pandas/core/frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# ...
